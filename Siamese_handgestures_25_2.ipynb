# %%
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D,Dropout
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras.initializers import RandomNormal
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import numpy.random as rng
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn.utils import shuffle
# %matplotlib inline

input_shape = (105, 105, 3)
left_input = Input(input_shape)
right_input = Input(input_shape)
#build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(Conv2D(64,(10,10),activation='relu',input_shape=input_shape,kernel_initializer=RandomNormal(mean=0.,stddev=0.01),kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128,(7,7),activation='relu',kernel_initializer=RandomNormal(mean=0.,stddev=0.01),kernel_regularizer=l2(2e-4),bias_initializer=RandomNormal(mean=0.5,stddev=0.01)))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128,(4,4),activation='relu',kernel_initializer=RandomNormal(mean=0.,stddev=0.01),kernel_regularizer=l2(2e-4),bias_initializer=RandomNormal(mean=0.5,stddev=0.01)))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(256,(4,4),activation='relu',kernel_initializer=RandomNormal(mean=0.,stddev=0.01),kernel_regularizer=l2(2e-4),bias_initializer=RandomNormal(mean=0.5,stddev=0.01)))
convnet.add(MaxPooling2D())
convnet.add(Flatten())
convnet.add(Dense(512,activation="sigmoid",kernel_initializer=RandomNormal(mean=0.,stddev=0.01),kernel_regularizer=l2(2e-4),bias_initializer=RandomNormal(mean=0.5,stddev=0.01)))

#call the convnet Sequential model on each of the input tensors so params will be shared
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1,activation='sigmoid',bias_initializer=RandomNormal(mean=0.5,stddev=0.01))(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

optimizer = Adam(0.00004)
#//TODO: get layerwise learning rates and momentum annealing scheme described in paperworking
siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer)

siamese_net.summary()
# Out:
# Model: "model_22"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_43 (InputLayer)           (None, 105, 105, 3)  0
# __________________________________________________________________________________________________
# input_44 (InputLayer)           (None, 105, 105, 3)  0
# __________________________________________________________________________________________________
# sequential_22 (Sequential)      (None, 512)          2387776     input_43[0][0]
#                                                                  input_44[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 512)          0           sequential_22[1][0]
#                                                                  sequential_22[2][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1)            513         lambda_22[0][0]
# ==================================================================================================
# Total params: 2,388,289
# Trainable params: 2,388,289
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data_path = '/content/gdrive/My Drive/Handgestures-25'
train_path = os.path.join(data_path,'train')
valid_path = os.path.join(data_path,'valid')

def loadimgs(path):
    if path == '/content/gdrive/My Drive/Handgestures-25/train':
        X = np.zeros((25,200,105,105,3))
    else:
        X = np.zeros((25,50,105,105,3))
    labels = {}
    for i,name in enumerate(os.listdir(path)):
        print(i)
        print(name)
        class_path = os.path.join(path,name)
        print(len(os.listdir(class_path)))
        labels[name] = i
        for j,f in enumerate(os.listdir(class_path)):
            #print(f)
            img_path = os.path.join(class_path,f)
            img = cv2.imread(img_path)
            X[i,j,:,:,:] = img
    return X,labels

# %%
X,c = loadimgs(train_path)
Xval,cval = loadimgs(valid_path)
data = [X,c,Xval,cval]
# Out:
# 0
# fist
# 200
# 1
# catch
# 200
# 2
# one
# 200
# 3
# cross-two
# 200
# 4
# six
# 200
# 5
# prayer
# 200
# 6
# cross-one
# 200
# 7
# five
# 200
# 8
# rock
# 200
# 9
# fantastic
# 200
# 10
# two
# 200
# 11
# gun
# 200
# 12
# four
# 200
# 13
# interlocked
# 200
# 14
# pinch
# 200
# 15
# thumb
# 200
# 16
# three
# 200
# 17
# timeout
# 200
# 18
# together
# 200
# 19
# bird
# 200
# 20
# heart
# 200
# 21
# diamond
# 200
# 22
# seven
# 200
# 23
# fist-two
# 200
# 24
# heart-two
# 200
# 0
# six
# 50
# 1
# cross-two
# 50
# 2
# pinch
# 50
# 3
# prayer
# 50
# 4
# one
# 50
# 5
# fist
# 50
# 6
# fantastic
# 50
# 7
# two
# 50
# 8
# catch
# 50
# 9
# five
# 50
# 10
# interlocked
# 50
# 11
# rock
# 50
# 12
# together
# 50
# 13
# four
# 50
# 14
# gun
# 50
# 15
# three
# 50
# 16
# cross-one
# 50
# 17
# thumb
# 50
# 18
# heart-two
# 50
# 19
# fist-two
# 50
# 20
# bird
# 50
# 21
# seven
# 50
# 22
# timeout
# 50
# 23
# heart
# 50
# 24
# diamond
# 50

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self,data):
        self.data = {}
        self.categories = {}
        self.info = {}
        self.data['train'] = data[0]
        self.categories['train'] = data[1]
        self.data['val'] = data[2]
        self.categories['val'] = data[3]
        
    def get_batch(self,batch_size,s="train"):
        """Create batch of n pairs, half same class, half different class"""
        X=self.data[s]
        n_classes, n_examples, w, h ,ch = X.shape

        #randomly sample several classes to use in the batch
        categories = rng.choice(n_classes,size=(batch_size,),replace=True)
        #initialize 2 empty arrays for the input image batch
        pairs=[np.zeros((batch_size, h, w, 3)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets=np.zeros((batch_size,))
        targets[batch_size//2:] = 1
        for i in range(batch_size):
            category = categories[i]
            idx_1 = rng.randint(0, n_examples)
            pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 3)
            idx_2 = rng.randint(0, n_examples)
            #pick images of same class for 1st half, different for 2nd
            if i >= batch_size // 2:
                category_2 = category  
            else: 
                #add a random number to the category modulo n classes to ensure 2nd image has
                # ..different category
                category_2 = (category + rng.randint(1,n_classes)) % n_classes
            pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h, 3)
        return pairs, targets    

    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size,s)
            yield (pairs, targets)    

    def make_oneshot_task(self,N,s="val"):
        if N>25:
            print('exceeds number of classes')
            return
        else:
            X = self.data[s]
            n_classes,n_examples,w,h,c = X.shape
            indices = rng.randint(0,n_examples,size=(N,))
            categories = rng.choice(n_classes,size=(N,),replace=False)
            true_category = categories[0]
            ex1,ex2 = rng.choice(n_examples,replace=False,size=(2,))
            test_image = np.asarray([X[true_category,ex1,:,:,:]]*N).reshape(N,w,h,3)
            support_set = X[categories,indices,:,:,:]
            support_set[0,:,:,:] = X[true_category,ex2]
            support_set = support_set.reshape(N,w,h,3)
            targets = np.zeros((N,))
            targets[0] = 1
            targets, test_image, support_set = shuffle(targets, test_image, support_set)
            pairs = [test_image,support_set]
            return pairs, targets
        
    def test_oneshot(self,model,N,k,s="val",verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            pass
            #print("Evaluating model on {} random {} way one-shot learning tasks ...".format(k,N))
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N,s)
            probs = model.predict(inputs)
            if np.argmax(probs) == np.argmax(targets):
                n_correct+=1
        percent_correct = (100.0*n_correct / k)
        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".format(percent_correct,N))
        return percent_correct
    
    def train(self, model, epochs, verbosity):
        model.fit_generator(self.generate(batch_size))

# %%
loader = Siamese_Loader(data)

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc,w,h,ch = X.shape
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h,3))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h,:] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def plot_oneshot_task(pairs):
    """Takes a one-shot task given to a siamese net and  """
    fig,(ax1,ax2) = plt.subplots(2)
    ax1.imshow(pairs[0][0].reshape(105,105,3).astype('uint8'))
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.imshow(img.astype('uint8'))
    plt.xticks([])
    plt.yticks([])
    plt.show()
#example of a one-shot learning task
pairs, targets = loader.make_oneshot_task(20,"train")
plot_oneshot_task(pairs)

# %%
#Training loop
print("!")
training_losses = []
val_accs = []
evaluate_every = 100 # interval for evaluating on one-shot tasks``
loss_every=100 # interval for printing loss (iterations)
batch_size = 64
n_iter = 10000
PATH = '/content/gdrive/My Drive'
N_way = 25 # how many classes for testing one-shot tasks>
n_val = 400 #how mahy one-shot tasks to validate on?
best = -1
weights_path = os.path.join(PATH, "weights.h5")
print("training")
for i in range(1, n_iter):
    (inputs,targets)=loader.get_batch(batch_size)
    loss=siamese_net.train_on_batch(inputs,targets)
    #print(loss)
    if i % evaluate_every == 0:
        print("evaluating")
        val_acc = loader.test_oneshot(siamese_net,N_way,n_val,verbose=True)
        val_accs.append(val_acc)
        if val_acc >= best:
            #print("saving")
            siamese_net.save(weights_path)
            best=val_acc

    if i % loss_every == 0:
        training_losses.append(loss)
        print("iteration {}, training loss: {:.4f},".format(i,loss))
# Out:
# !
# training
# evaluating
# Got an average of 8.25% 25 way one-shot learning accuracy
# iteration 100, training loss: 0.7108,
# evaluating
# Got an average of 16.25% 25 way one-shot learning accuracy
# iteration 200, training loss: 0.7209,
# evaluating
# Got an average of 17.25% 25 way one-shot learning accuracy
# iteration 300, training loss: 0.5522,
# evaluating
# Got an average of 20.0% 25 way one-shot learning accuracy
# iteration 400, training loss: 0.4872,
# evaluating
# Got an average of 28.0% 25 way one-shot learning accuracy
# iteration 500, training loss: 0.4969,
# evaluating
# Got an average of 28.5% 25 way one-shot learning accuracy
# iteration 600, training loss: 0.4819,
# evaluating
# Got an average of 36.75% 25 way one-shot learning accuracy
# iteration 700, training loss: 0.4019,
# evaluating
# Got an average of 38.25% 25 way one-shot learning accuracy
# iteration 800, training loss: 0.3896,
# evaluating
# Got an average of 41.75% 25 way one-shot learning accuracy
# iteration 900, training loss: 0.4007,
# evaluating
# Got an average of 45.5% 25 way one-shot learning accuracy
# iteration 1000, training loss: 0.3692,
# evaluating
# Got an average of 52.5% 25 way one-shot learning accuracy
# iteration 1100, training loss: 0.2016,
# evaluating
# Got an average of 49.25% 25 way one-shot learning accuracy
# iteration 1200, training loss: 0.3641,
# evaluating
# Got an average of 52.75% 25 way one-shot learning accuracy
# iteration 1300, training loss: 0.2475,
# evaluating
# Got an average of 54.25% 25 way one-shot learning accuracy
# iteration 1400, training loss: 0.2371,
# evaluating
# Got an average of 58.25% 25 way one-shot learning accuracy
# iteration 1500, training loss: 0.1760,
# evaluating
# Got an average of 62.25% 25 way one-shot learning accuracy
# iteration 1600, training loss: 0.2369,
# evaluating
# Got an average of 67.25% 25 way one-shot learning accuracy
# iteration 1700, training loss: 0.2845,
# evaluating
# Got an average of 72.75% 25 way one-shot learning accuracy
# iteration 1800, training loss: 0.2566,
# evaluating
# Got an average of 68.75% 25 way one-shot learning accuracy
# iteration 1900, training loss: 0.2075,
# evaluating
# Got an average of 68.75% 25 way one-shot learning accuracy
# iteration 2000, training loss: 0.2421,
# evaluating
# Got an average of 77.25% 25 way one-shot learning accuracy
# iteration 2100, training loss: 0.1547,
# evaluating
# Got an average of 73.0% 25 way one-shot learning accuracy
# iteration 2200, training loss: 0.1489,
# evaluating
# Got an average of 79.75% 25 way one-shot learning accuracy
# iteration 2300, training loss: 0.1484,
# evaluating
# Got an average of 82.75% 25 way one-shot learning accuracy
# iteration 2400, training loss: 0.1675,
# evaluating
# Got an average of 79.0% 25 way one-shot learning accuracy
# iteration 2500, training loss: 0.1676,
# evaluating
# Got an average of 82.5% 25 way one-shot learning accuracy
# iteration 2600, training loss: 0.2074,
# evaluating
# Got an average of 83.5% 25 way one-shot learning accuracy
# iteration 2700, training loss: 0.1750,
# evaluating
# Got an average of 83.0% 25 way one-shot learning accuracy
# iteration 2800, training loss: 0.2189,
# evaluating
# Got an average of 86.5% 25 way one-shot learning accuracy
# iteration 2900, training loss: 0.1158,
# evaluating
# Got an average of 88.0% 25 way one-shot learning accuracy
# iteration 3000, training loss: 0.1324,
# evaluating
# Got an average of 86.75% 25 way one-shot learning accuracy
# iteration 3100, training loss: 0.1255,
# evaluating
# Got an average of 91.5% 25 way one-shot learning accuracy
# iteration 3200, training loss: 0.1168,
# evaluating
# Got an average of 90.25% 25 way one-shot learning accuracy
# iteration 3300, training loss: 0.1344,
# evaluating
# Got an average of 90.25% 25 way one-shot learning accuracy
# iteration 3400, training loss: 0.0990,
# evaluating
# Got an average of 90.75% 25 way one-shot learning accuracy
# iteration 3500, training loss: 0.1193,
# evaluating
# Got an average of 91.0% 25 way one-shot learning accuracy
# iteration 3600, training loss: 0.1128,
# evaluating
# Got an average of 93.5% 25 way one-shot learning accuracy
# iteration 3700, training loss: 0.1006,
# evaluating
# Got an average of 92.25% 25 way one-shot learning accuracy
# iteration 3800, training loss: 0.0809,
# evaluating
# Got an average of 91.25% 25 way one-shot learning accuracy
# iteration 3900, training loss: 0.0752,
# evaluating
# Got an average of 95.5% 25 way one-shot learning accuracy
# iteration 4000, training loss: 0.1014,
# evaluating
# Got an average of 91.5% 25 way one-shot learning accuracy
# iteration 4100, training loss: 0.0801,
# evaluating
# Got an average of 92.5% 25 way one-shot learning accuracy
# iteration 4200, training loss: 0.1404,
# evaluating
# Got an average of 93.75% 25 way one-shot learning accuracy
# iteration 4300, training loss: 0.0828,
# evaluating
# Got an average of 94.75% 25 way one-shot learning accuracy
# iteration 4400, training loss: 0.0844,
# evaluating
# Got an average of 95.5% 25 way one-shot learning accuracy
# iteration 4500, training loss: 0.1439,
# evaluating
# Got an average of 95.5% 25 way one-shot learning accuracy
# iteration 4600, training loss: 0.1189,
# evaluating
# Got an average of 92.5% 25 way one-shot learning accuracy
# iteration 4700, training loss: 0.0967,
# evaluating
# Got an average of 96.25% 25 way one-shot learning accuracy
# iteration 4800, training loss: 0.1075,
# evaluating
# Got an average of 95.0% 25 way one-shot learning accuracy
# iteration 4900, training loss: 0.0691,
# evaluating
# Got an average of 96.0% 25 way one-shot learning accuracy
# iteration 5000, training loss: 0.0939,
# evaluating
# Got an average of 96.75% 25 way one-shot learning accuracy
# iteration 5100, training loss: 0.1060,
# evaluating
# Got an average of 95.5% 25 way one-shot learning accuracy
# iteration 5200, training loss: 0.0722,
# evaluating
# Got an average of 94.75% 25 way one-shot learning accuracy
# iteration 5300, training loss: 0.0976,
# evaluating
# Got an average of 95.5% 25 way one-shot learning accuracy
# iteration 5400, training loss: 0.0944,
# evaluating
# Got an average of 97.5% 25 way one-shot learning accuracy
# iteration 5500, training loss: 0.0989,
# evaluating
# Got an average of 96.75% 25 way one-shot learning accuracy
# iteration 5600, training loss: 0.0607,
# evaluating
# Got an average of 97.75% 25 way one-shot learning accuracy
# iteration 5700, training loss: 0.0694,
# evaluating
# Got an average of 97.0% 25 way one-shot learning accuracy
# iteration 5800, training loss: 0.1309,
# evaluating
# Got an average of 98.0% 25 way one-shot learning accuracy
# iteration 5900, training loss: 0.0621,
# evaluating
# Got an average of 98.25% 25 way one-shot learning accuracy
# iteration 6000, training loss: 0.0810,
# evaluating
# Got an average of 98.25% 25 way one-shot learning accuracy
# iteration 6100, training loss: 0.0538,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 6200, training loss: 0.0591,
# evaluating
# Got an average of 97.5% 25 way one-shot learning accuracy
# iteration 6300, training loss: 0.0561,
# evaluating
# Got an average of 98.0% 25 way one-shot learning accuracy
# iteration 6400, training loss: 0.0493,
# evaluating
# Got an average of 97.75% 25 way one-shot learning accuracy
# iteration 6500, training loss: 0.0856,
# evaluating
# Got an average of 99.0% 25 way one-shot learning accuracy
# iteration 6600, training loss: 0.0611,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 6700, training loss: 0.0505,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 6800, training loss: 0.0549,
# evaluating
# Got an average of 98.25% 25 way one-shot learning accuracy
# iteration 6900, training loss: 0.0512,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 7000, training loss: 0.0449,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 7100, training loss: 0.0574,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 7200, training loss: 0.0529,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 7300, training loss: 0.0661,
# evaluating
# Got an average of 99.0% 25 way one-shot learning accuracy
# iteration 7400, training loss: 0.0515,
# evaluating
# Got an average of 99.75% 25 way one-shot learning accuracy
# iteration 7500, training loss: 0.0669,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 7600, training loss: 0.0424,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 7700, training loss: 0.0397,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 7800, training loss: 0.0519,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 7900, training loss: 0.0391,
# evaluating
# Got an average of 99.5% 25 way one-shot learning accuracy
# iteration 8000, training loss: 0.0423,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 8100, training loss: 0.0522,
# evaluating
# Got an average of 99.25% 25 way one-shot learning accuracy
# iteration 8200, training loss: 0.0353,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 8300, training loss: 0.0404,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 8400, training loss: 0.0393,
# evaluating
# Got an average of 99.5% 25 way one-shot learning accuracy
# iteration 8500, training loss: 0.0431,
# evaluating
# Got an average of 99.25% 25 way one-shot learning accuracy
# iteration 8600, training loss: 0.0462,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 8700, training loss: 0.0648,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 8800, training loss: 0.0390,
# evaluating
# Got an average of 99.5% 25 way one-shot learning accuracy
# iteration 8900, training loss: 0.0400,
# evaluating
# Got an average of 99.25% 25 way one-shot learning accuracy
# iteration 9000, training loss: 0.0529,
# evaluating
# Got an average of 98.25% 25 way one-shot learning accuracy
# iteration 9100, training loss: 0.0329,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 9200, training loss: 0.0346,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 9300, training loss: 0.0332,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 9400, training loss: 0.0373,
# evaluating
# Got an average of 98.5% 25 way one-shot learning accuracy
# iteration 9500, training loss: 0.0398,
# evaluating
# Got an average of 99.0% 25 way one-shot learning accuracy
# iteration 9600, training loss: 0.0421,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 9700, training loss: 0.0320,
# evaluating
# Got an average of 98.25% 25 way one-shot learning accuracy
# iteration 9800, training loss: 0.0430,
# evaluating
# Got an average of 98.75% 25 way one-shot learning accuracy
# iteration 9900, training loss: 0.0431,

# %%
iters = range(100,10000,100)
plt.plot(iters,training_losses,'b-')
plt.xlabel('number of iterations')
plt.ylabel('training loss')
plt.show()

# %%
plt.plot(iters,val_accs,'b-')
plt.xlabel('number of iterations')
plt.ylabel('validation accuracy')
plt.show()

# %%
ways = np.arange(1, 25, 1)
resume =  False
val_accs, train_accs = [], []
trials = 1000
for N in ways:
    val_accs.append(loader.test_oneshot(siamese_net, N,trials, "val", verbose=True))
    train_accs.append(loader.test_oneshot(siamese_net, N,trials, "train", verbose=True))
    
#plot the accuracy vs num categories for each
plt.plot(ways, val_accs, "m")
plt.plot(ways, train_accs, "y")
plt.show()
# Out:
# Got an average of 100.0% 1 way one-shot learning accuracy
# Got an average of 100.0% 1 way one-shot learning accuracy
# Got an average of 100.0% 2 way one-shot learning accuracy
# Got an average of 100.0% 2 way one-shot learning accuracy
# Got an average of 99.9% 3 way one-shot learning accuracy
# Got an average of 100.0% 3 way one-shot learning accuracy
# Got an average of 99.6% 4 way one-shot learning accuracy
# Got an average of 100.0% 4 way one-shot learning accuracy
# Got an average of 99.9% 5 way one-shot learning accuracy
# Got an average of 100.0% 5 way one-shot learning accuracy
# Got an average of 99.4% 6 way one-shot learning accuracy
# Got an average of 100.0% 6 way one-shot learning accuracy
# Got an average of 99.5% 7 way one-shot learning accuracy
# Got an average of 100.0% 7 way one-shot learning accuracy
# Got an average of 99.6% 8 way one-shot learning accuracy
# Got an average of 100.0% 8 way one-shot learning accuracy
# Got an average of 99.3% 9 way one-shot learning accuracy
# Got an average of 100.0% 9 way one-shot learning accuracy
# Got an average of 99.6% 10 way one-shot learning accuracy
# Got an average of 100.0% 10 way one-shot learning accuracy
# Got an average of 99.8% 11 way one-shot learning accuracy
# Got an average of 100.0% 11 way one-shot learning accuracy
# Got an average of 99.7% 12 way one-shot learning accuracy
# Got an average of 100.0% 12 way one-shot learning accuracy
# Got an average of 99.2% 13 way one-shot learning accuracy
# Got an average of 99.9% 13 way one-shot learning accuracy
# Got an average of 99.5% 14 way one-shot learning accuracy
# Got an average of 100.0% 14 way one-shot learning accuracy
# Got an average of 99.5% 15 way one-shot learning accuracy
# Got an average of 100.0% 15 way one-shot learning accuracy
# Got an average of 99.6% 16 way one-shot learning accuracy
# Got an average of 100.0% 16 way one-shot learning accuracy
# Got an average of 98.8% 17 way one-shot learning accuracy
# Got an average of 99.9% 17 way one-shot learning accuracy
# Got an average of 99.5% 18 way one-shot learning accuracy
# Got an average of 100.0% 18 way one-shot learning accuracy
# Got an average of 99.3% 19 way one-shot learning accuracy
# Got an average of 100.0% 19 way one-shot learning accuracy
# Got an average of 99.6% 20 way one-shot learning accuracy
# Got an average of 100.0% 20 way one-shot learning accuracy
# Got an average of 99.2% 21 way one-shot learning accuracy
# Got an average of 100.0% 21 way one-shot learning accuracy
# Got an average of 99.5% 22 way one-shot learning accuracy
# Got an average of 100.0% 22 way one-shot learning accuracy
# Got an average of 99.3% 23 way one-shot learning accuracy
# Got an average of 100.0% 23 way one-shot learning accuracy
# Got an average of 99.1% 24 way one-shot learning accuracy
# Got an average of 100.0% 24 way one-shot learning accuracy

# %%
fig,ax = plt.subplots(1)
ax.plot(ways,val_accs,"m",label="Siamese(val set)")
ax.plot(ways,train_accs,"y",label="Siamese(train set)")

plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Siamese Neural Network performance on hand gesture classification")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = loader.make_oneshot_task(20,"val")
plt.show()

print(inputs[0].shape)
plot_oneshot_task(inputs)
p=siamese_net.predict(inputs)
print(p)
# Out:
# (20, 105, 105, 3)
# [[1.8250860e-08]
#  [2.5019426e-07]
#  [1.4675210e-07]
#  [2.4047293e-04]
#  [9.9855429e-01]
#  [5.8770989e-04]
#  [4.3626023e-05]
#  [1.5233112e-05]
#  [3.7905090e-06]
#  [4.8330658e-05]
#  [2.1648725e-08]
#  [6.2390944e-07]
#  [2.9497935e-05]
#  [1.8704794e-02]
#  [1.5935573e-08]
#  [3.0916076e-06]
#  [2.6796525e-04]
#  [6.4530758e-07]
#  [9.1132242e-06]
#  [3.2094601e-06]]

# %%
from keras.models import load_model
model_path = '/content/gdrive/My Drive/weights.h5'
model = load_model(model_path)
